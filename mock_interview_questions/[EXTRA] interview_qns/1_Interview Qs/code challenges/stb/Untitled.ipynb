# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Mock dataset.xlsx")

# %%
df.head()
# Out:
#    case  quarter  R.mth        age    country 1st time visitor  \
# 0     4        1      1  30-34 yrs  Indonesia               No
# 1    59        1      1  50-54 yrs  Indonesia               No
# 2    83        1      1  40-44 yrs  Indonesia               No
# 3   250        1      1  20-24 yrs  Indonesia               No
# 4   260        1      1  55-59 yrs  Indonesia               No
#
#   nbr visit past 3 yrs mode of arrival                           carrier  \
# 0                   50             Sea                               NaN
# 1                   18             Air                     Valuair (VLU)
# 2                    3             Air  Singapore Airlines Limited (SIA)
# 3                   11             Sea                               NaN
# 4                    9             Air            Garuda Indonesia (GIA)
#
#                                    purpose of visit  ... companion_4  \
# 0  Others - Personal (e.g. weddings, funerals, etc)  ...         NaN
# ...

# %%
df.shape
# Out:
# (2952, 32)

# %%
df.isnull().sum()
# Out:
# case                       0
# quarter                    0
# R.mth                      0
# age                        0
# country                    0
# 1st time visitor           0
# nbr visit past 3 yrs     334
# mode of arrival            0
# carrier                 1501
# purpose of visit           0
# purpose of visit_Grp       0
# pov6a                      0
# Mono-SIN                   0
# Last Port                  1
# Next Port                  1
# length of stay             0
# Travel Type                0
# gender                     0
# marital status             1
# companion_1                1
# companion_2             2508
# companion_3             2820
# companion_4             2926
# companion_5             2945
# companion_6             2952
# accomodation ($)           0
# shop ($)                   0
# fnb ($)                    0
# transport ($)              0
# medical ($)                0
# others ($)                 0
# Total                      0
# ...

# %%
df.case.nunique()
# Out:
# 2952

# %%
for x in df.columns:
    print(x)
    print(df[x].value_counts())
# Out:
# case
# 17804    1
# 13644    1
# 11609    1
# 1368     1
# 11607    1
#         ..
# 17003    1
# 14996    1
# 10397    1
# 17041    1
# 13831    1
# Name: case, Length: 2952, dtype: int64
# quarter
# 3    819
# 4    735
# 1    723
# 2    675
# Name: quarter, dtype: int64
# R.mth
# 12    356
# 7     298
# 1     285
# 4     283
# 9     268
# 8     253
# 3     220
# 2     218
# 6     202
# 10    196
# 5     190
# 11    183
# Name: R.mth, dtype: int64
# age
# 30-34 yrs         477
# 35-39 yrs         427
# 40-44 yrs         390
# 25-29 yrs         353
# 20-24 yrs         295
# 45-49 yrs         275
# 50-54 yrs         252
# 55-59 yrs         164
# 60-64 yrs         113
# 15-19 yrs         105
# 65 yrs & above     88
# 12-14 yrs          13
# Name: age, dtype: int64
# country
# Indonesia    2952
# Name: country, dtype: int64
# 1st time visitor
# No     2618
# Yes     334
# Name: 1st time visitor, dtype: int64
# nbr visit past 3 yrs
# 3      302
# 2      301
# 5      229
# 10     228
# ...
